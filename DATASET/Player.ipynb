# %%
import pandas as pd
  
# making data frame from csv file
nba = pd.read_csv("Player1.csv")

# %%
nba
# Out:
#      Player_Id      Player_Name         DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly    7/8/1972    Left_Hand    Right-arm medium
# 1            2      BB McCullum   9/27/1981   Right_Hand    Right-arm medium
# 2            3       RT Ponting  12/19/1974   Right_Hand    Right-arm medium
# 3            4        DJ Hussey   7/15/1977   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  10/17/1980   Right_Hand  Right-arm offbreak
# ..         ...              ...         ...          ...                 ...
# 518        517          AL Hill         NaN          NaN                 NaN
# 519        518        RJ Tucker         NaN          NaN                 NaN
# 520        519      Subroto Das         NaN          NaN                 NaN
# 521        520     K Srinivasan         NaN          NaN                 NaN
# 522        521        VK Sharma         NaN          NaN                 NaN
#
#          Country  Is_Umpire
# ...

# %%
nba["Player_dismissal_Id"].fillna("0", inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Player_dismissal_Id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-3dacb06b3d12> in <module>
# ...

# %%
nba["Player_dissimal_Id"].fillna("0", inplace = True)

# %%
nba
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0         335987           1        1        1                1
# 1         335987           1        1        2                1
# 2         335987           1        1        3                1
# 3         335987           1        1        4                1
# 4         335987           1        1        5                1
# ...          ...         ...      ...      ...              ...
# 136585    981024           2       20        2                2
# 136586    981024           2       20        3                2
# 136587    981024           2       20        4                2
# 136588    981024           2       20        5                2
# 136589    981024           2       20        6                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                     2           1                         1               2
# ...

# %%
nba["Player_dissimal_Id"].replace(to_replace =" ",value ="0")
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#          ...
# 136585      0
# 136586    434
# 136587      0
# 136588      0
# 136589      0
# Name: Player_dissimal_Id, Length: 136590, dtype: object

# %%
nba
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0         335987           1        1        1                1
# 1         335987           1        1        2                1
# 2         335987           1        1        3                1
# 3         335987           1        1        4                1
# 4         335987           1        1        5                1
# ...          ...         ...      ...      ...              ...
# 136585    981024           2       20        2                2
# 136586    981024           2       20        3                2
# 136587    981024           2       20        4                2
# 136588    981024           2       20        5                2
# 136589    981024           2       20        6                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                     2           1                         1               2
# ...

# %%
nba["Player_dissimal_Id"]=nba["Player_dissimal_Id"].replace(to_replace =" ",value ="0")

# %%
nba
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0         335987           1        1        1                1
# 1         335987           1        1        2                1
# 2         335987           1        1        3                1
# 3         335987           1        1        4                1
# 4         335987           1        1        5                1
# ...          ...         ...      ...      ...              ...
# 136585    981024           2       20        2                2
# 136586    981024           2       20        3                2
# 136587    981024           2       20        4                2
# 136588    981024           2       20        5                2
# 136589    981024           2       20        6                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                     2           1                         1               2
# ...

# %%
nba["Extra_Runs"]=nba["Extra_Runs"].replace(to_replace =" ",value ="0")

# %%
nba
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0         335987           1        1        1                1
# 1         335987           1        1        2                1
# 2         335987           1        1        3                1
# 3         335987           1        1        4                1
# 4         335987           1        1        5                1
# ...          ...         ...      ...      ...              ...
# 136585    981024           2       20        2                2
# 136586    981024           2       20        3                2
# 136587    981024           2       20        4                2
# 136588    981024           2       20        5                2
# 136589    981024           2       20        6                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                     2           1                         1               2
# ...

# %%
nba["Fielder_Id"]=nba["Fielder_Id"].replace(to_replace =" ",value ="0")

# %%
nba
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0         335987           1        1        1                1
# 1         335987           1        1        2                1
# 2         335987           1        1        3                1
# 3         335987           1        1        4                1
# 4         335987           1        1        5                1
# ...          ...         ...      ...      ...              ...
# 136585    981024           2       20        2                2
# 136586    981024           2       20        3                2
# 136587    981024           2       20        4                2
# 136588    981024           2       20        5                2
# 136589    981024           2       20        6                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                     2           1                         1               2
# ...

# %%
nba.to_csv('Ball1.csv')

# %%
nba['DOB1'] = nba['DOB'].dt.strftime('%Y/%m/%d')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-eed7aa7cb0e9> in <module>
# ----> 1 nba['DOB1'] = nba['DOB'].dt.strftime('%Y/%m/%d')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
# ...

# %%
nba['DOB'] = pd.to_datetime(nba['DOB'])

# %%
nba
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly 1972-07-08    Left_Hand    Right-arm medium
# 1            2      BB McCullum 1981-09-27   Right_Hand    Right-arm medium
# 2            3       RT Ponting 1974-12-19   Right_Hand    Right-arm medium
# 3            4        DJ Hussey 1977-07-15   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez 1980-10-17   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        517          AL Hill        NaT          NaN                 NaN
# 519        518        RJ Tucker        NaT          NaN                 NaN
# 520        519      Subroto Das        NaT          NaN                 NaN
# 521        520     K Srinivasan        NaT          NaN                 NaN
# 522        521        VK Sharma        NaT          NaN                 NaN
#
#          Country  Is_Umpire
# ...

# %%
nba.to_csv('Player2.csv')
